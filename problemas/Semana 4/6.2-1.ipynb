# %% [markdown]
# # Enunciado
# Utilizando la siguiente figura como modelo, ilustra la operación e ```MAX-HEAPIFY(A,3)``` en el arreglo $A=<27,17,3,16,13,10,1,5,7,12,4,8,9,0>$
# ![WhatsApp Image 2024-10-03 at 07.33.05_d475b81a.jpg](attachment:896a81da-ce68-4b47-aacf-84c02a7b7c5b.jpg)

# %% [markdown]
# # Solución
# ![WhatsApp Image 2024-10-03 at 08.07.05_746f620e.jpg](attachment:cafb2020-ed01-4db3-af0d-f276c27fdf1f.jpg)
