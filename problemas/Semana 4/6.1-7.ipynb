# %% [markdown]
# # Enunciado
# ¿Es el arreglo con valores 〈33, 19, 20, 15, 13, 10, 2, 13, 16, 12〉 un max-heap?

# %% [markdown]
# # Solución
#
# Realizamos el grafo para representar el arreglo dado:
# ![6.1-7.png](attachment:caddfa8e-3d94-4f31-8009-980b041b629c.png)
# Pero vemos que el nodo 5 es mayor que el nodo 2, que es su nodo padre. Lo mismo pasa con el nodo 5 y 4. Por tanto, el grafo no se trata de un max-heap.
