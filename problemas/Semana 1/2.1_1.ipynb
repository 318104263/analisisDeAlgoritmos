# %% [markdown]
# ## Enunciado
# Using the following figure, illustrate the operation of INSERITON-SORT on an array initially ontainign the sequence <31, 41, 59, 26, 41, 58>
# ![image.png](attachment:263b1782-13d7-41b5-a22f-97b25e282db2.png)

# %% [markdown]
# ## Solución
# ![WhatsApp Image 2024-09-02 at 17.41.47_31ab2a89.jpg](attachment:23c31ace-8c6f-40bf-abb9-49f8a4ca62d1.jpg)
